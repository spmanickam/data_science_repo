# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#General-Commands" data-toc-modified-id="General-Commands-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>General Commands</a></span></li><li><span><a href="#Magic-Functions" data-toc-modified-id="Magic-Functions-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Magic Functions</a></span></li><li><span><a href="#DATA-SCIENCE-PROJECT-TEMPLATE:-COOKIE-CUTTER" data-toc-modified-id="DATA-SCIENCE-PROJECT-TEMPLATE:-COOKIE-CUTTER-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>DATA SCIENCE PROJECT TEMPLATE: COOKIE CUTTER</a></span></li><li><span><a href="#VERSION-CONTROL" data-toc-modified-id="VERSION-CONTROL-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>VERSION CONTROL</a></span></li><li><span><a href="#DATASCIENCE-PROJECT-CYCLE" data-toc-modified-id="DATASCIENCE-PROJECT-CYCLE-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>DATASCIENCE PROJECT CYCLE</a></span></li><li><span><a href="#TO-DO:-EXTRACT-DATA-FROM-MYSQL/SQLSERVER" data-toc-modified-id="TO-DO:-EXTRACT-DATA-FROM-MYSQL/SQLSERVER-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>TO DO: EXTRACT DATA FROM MYSQL/SQLSERVER</a></span></li><li><span><a href="#Extracting_data_from_db_template" data-toc-modified-id="Extracting_data_from_db_template-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Extracting_data_from_db_template</a></span></li><li><span><a href="#Extracting_data_from_API" data-toc-modified-id="Extracting_data_from_API-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Extracting_data_from_API</a></span></li><li><span><a href="#HTML-RENDERING" data-toc-modified-id="HTML-RENDERING-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>HTML RENDERING</a></span></li><li><span><a href="#TO-DO:--Web-Scraping-using-Request-&amp;-BeautifulSoup" data-toc-modified-id="TO-DO:--Web-Scraping-using-Request-&amp;-BeautifulSoup-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>TO DO:  Web Scraping using Request &amp; BeautifulSoup</a></span></li><li><span><a href="#IMPORTING-TITANIC-DATASET" data-toc-modified-id="IMPORTING-TITANIC-DATASET-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>IMPORTING TITANIC DATASET</a></span><ul class="toc-item"><li><span><a href="#Using-Environment-variable-abd-request.session" data-toc-modified-id="Using-Environment-variable-abd-request.session-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>Using Environment variable abd request.session</a></span></li><li><span><a href="#Using-pandas" data-toc-modified-id="Using-pandas-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>Using pandas</a></span></li></ul></li><li><span><a href="#LOGGING" data-toc-modified-id="LOGGING-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>LOGGING</a></span><ul class="toc-item"><li><span><a href="#TO-DO:-LOGGING-USING-YAML-config-file" data-toc-modified-id="TO-DO:-LOGGING-USING-YAML-config-file-12.1"><span class="toc-item-num">12.1&nbsp;&nbsp;</span>TO DO: LOGGING USING YAML config file</a></span></li></ul></li><li><span><a href="#OS-INFO" data-toc-modified-id="OS-INFO-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>OS INFO</a></span></li><li><span><a href="#CONTINUE" data-toc-modified-id="CONTINUE-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>CONTINUE</a></span></li><li><span><a href="#PUBLIC-DATASETS" data-toc-modified-id="PUBLIC-DATASETS-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>PUBLIC DATASETS</a></span></li></ul></div>

# %% [markdown]
# ### General Commands

# %%
 #Line numbers keyboard shortcut: [ESC] + L

# %%
import datetime
print(datetime.datetime.now())
def myPrint(text):
    print(datetime.datetime.now(), 'My message: ', text)
# Out:
# 2018-09-09 16:33:58.642704

# %%
myPrint('my message 1')
# Out:
# 2018-09-09 16:33:58.737386 My message:  my message 1

# %%
# %env
# Out:
# {'KAFKA_HOME': '/Users/pinky/Downloads/SOFTWARE/kafka_2.11-1.0.0',
#  'SPARK_HOME': '/Users/pinky/Downloads/SOFTWARE/spark-2.3.1-bin-hadoop2.7',
#  'TERM_PROGRAM': 'Apple_Terminal',
#  'SHELL': '/bin/bash',
#  'TERM': 'xterm-color',
#  'TMPDIR': '/var/folders/cv/tlhjv00d1jn9yb_c725pk_9c0000gn/T/',
#  'Apple_PubSub_Socket_Render': '/private/tmp/com.apple.launchd.ATuYeDNSeU/Render',
#  'TERM_PROGRAM_VERSION': '361.1',
#  'KAFKA_CONF_DIF': '/Users/pinky/Downloads/SOFTWARE/kafka_2.11-1.0.0/config',
#  'TERM_SESSION_ID': '4F9F4B43-F955-4E52-9741-43F58FEFA5F3',
#  'USER': 'ganeshpillai',
#  'KAFKA_CLASSPATH': '/Users/pinky/Downloads/SOFTWARE/kafka_2.11-1.0.0/libs',
#  'CANOPY_HOME': '/Users/pinky/Library/Enthought/Canopy_64bit/User/',
#  'SSH_AUTH_SOCK': '/private/tmp/com.apple.launchd.HudQKtxW6X/Listeners',
#  '__CF_USER_TEXT_ENCODING': '0x1F5:0x0:0x0',
#  'VIRTUAL_ENV': '/Users/pinky/Library/Enthought/Canopy_64bit/User',
# ...

# %%
# !python --version
# Out:
# Python 3.6.5 :: Anaconda, Inc.

# %% [markdown]
# ### Magic Functions

# %%
# %matplotlib inline

# %%
 # Use % for single line
 # Use %% for multi line

# %%
# %%timeit x = range(1000)
max(x)
# Out:
# 70.7 µs ± 22 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
r100 = range(100)

# %%
# %%writefile test.txt
# this is written from jupyter r100
# Out:
# Overwriting test.txt

# %%
# !ls
# Out:
# Pluralsight_Python_data_science_Abhishek_kumar_1.ipynb
# images
# test.txt

# %%
# !cat test.txt
# Out:
# this is written from jupyter r100

# %%
# %%HTML
# <p> List1 </i>
# <p> List2 </i>
# Out:
# <p> List1 </i>
# <p> List2 </i>

# %%
# %%latex
# \begin{align}
# Gradient : \nabla J = - 2H^T (Y_HW)
# \end{align}
# Out:
# \begin{align}
# Gradient : \nabla J = - 2H^T (Y_HW)
# \end{align}

# %% [markdown]
# ### DATA SCIENCE PROJECT TEMPLATE: COOKIE CUTTER

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(filename='images/data_science_project_template.png', height=400, width=600)

# %% [raw]
# GANESH-PRO:module2 ganeshpillai$ conda install -y -c conda-forge cookiecutter
#
#
# GANESH-PRO:module2 ganeshpillai$ cookiecutter https://github.com/drivendata/cookiecutter-data-science
# You've downloaded /Users/pinky/.cookiecutters/cookiecutter-data-science before. Is it okay to delete and re-download it? [yes]: y
# project_name [project_name]: titanic
# repo_name [titanic]:
# author_name [Your name (or your organization/company/team)]: Ganesh Pillai
# description [A short description of the project.]: Pluralsight_Python_data_science_Abhishek_kumar
# Select open_source_license:
# 1 - MIT
# 2 - BSD-3-Clause
# 3 - No license file
# Choose from 1, 2, 3 [1]: 1
# s3_bucket [[OPTIONAL] your-bucket-for-syncing-data (do not include 's3://')]:
# aws_profile [default]:
# Select python_interpreter:
# 1 - python3
# 2 - python
# Choose from 1, 2 [1]: 1

# %% [raw]
# # FOR MAC ONLY install tree:
# # brew install tree

# %%
'''
GANESH-PRO:titanic ganeshpillai$ pwd
/Users/pinky/Downloads/LEARNING/PLURALSIGHT_Python_data_science_Abhishek_kumar/module2/titanic
GANESH-PRO:titanic ganeshpillai$ tree
.
├── LICENSE
├── Makefile
├── README.md
├── data
│   ├── external
│   ├── interim               # intermediate data
│   ├── processed             # final data used for medelling activities
│   └── raw                   # original data (don't modify)
├── docs
│   ├── Makefile
│   ├── commands.rst
│   ├── conf.py
│   ├── getting-started.rst
│   ├── index.rst
│   └── make.bat
├── models                     # contains model summaries
├── notebooks                  # contains Jupyter Notebooks 
├── references
├── reports
│   └── figures
├── requirements.txt
├── setup.py
├── src                       # source code (only .py files goes here)
│   ├── __init__.py           # to create a python module
│   ├── data                  # code for importin data
│   │   ├── __init__.py       
│   │   └── make_dataset.py
│   ├── features              # code for feature creation/manipulation
│   │   ├── __init__.py
│   │   └── build_features.py
│   ├── models
│   │   ├── __init__.py
│   │   ├── predict_model.py
│   │   └── train_model.py
│   └── visualization
│       ├── __init__.py
│       └── visualize.py
├── test_environment.py
└── tox.ini                      # for automated testing
'''

# %% [markdown]
# ### VERSION CONTROL

# %%
'''
GANESH-PRO:titanic ganeshpillai$ pwd
/Users/pinky/Downloads/LEARNING/PLURALSIGHT_Python_data_science_Abhishek_kumar/module2/titanic

GANESH-PRO:titanic ganeshpillai$ git init
Initialized empty Git repository in
/Users/pinky/Downloads/LEARNING/PLURALSIGHT_Python_data_science_Abhishek_kumar/module2/titanic/.git/

GANESH-PRO:titanic ganeshpillai$ git add .

GANESH-PRO:titanic ganeshpillai$ git commit -m "initial commit"
[master (root-commit) f128f7a] initial commit
 33 files changed, 998 insertions(+)
 create mode 100644 .gitignore
 ...etc...
 create mode 100644 src/visualization/visualize.py
 create mode 100644 test_environment.py
 create mode 100644 tox.ini

GANESH-PRO:titanic ganeshpillai$ git status
On branch master
nothing to commit, working directory clean

GANESH-PRO:titanic ganeshpillai$ git log --oneline
f128f7a initial commit

GANESH-PRO:titanic ganeshpillai$ ls -a
.			.gitignore		data			references		src
..			LICENSE			docs			reports			test_environment.py
.env			Makefile		models			requirements.txt	tox.ini
.git			README.md		notebooks		setup.py
'''

# %% [markdown]
# ### DATASCIENCE PROJECT CYCLE

# %%
Image(filename='images/data_science_project_lifecycle.png', height=400, width=600)

# %%
Sources:
    File
    Website
    API
    Database
    Forms
    Device

# %% [markdown]
# ### TO DO: EXTRACT DATA FROM MYSQL/SQLSERVER

# %% [markdown]
# ### Extracting_data_from_db_template

# %%
Image(filename='images/extracting_data_from_db_template.png', height=300, width=400)

# %% [markdown]
# ### Extracting_data_from_API

# %%
Image(filename='images/extracting_data_from_api_template.png', height=300, width=400)

# %% [markdown]
# ### HTML RENDERING

# %%
html_string = '''
<!doctype html>
<html lang=\"en\">
    "<head>
          <title>Doing Data Science With Python</title>
    </head>
    <body>
          <h1 style=\"color:#F15B2A;\">Doing Data Science With Python</h1>
          <p id=\"author\">Author : Abhishek Kumar</p>
    <p id=\"description\">This course will help you to perform various data science activities using python.</p>
          
          <h3 style=\"color:#404040\">Modules</h3>
          <table id=\"module\" style=\"width:100%\">
              <tr>
                <th>Title</th>
                <th>Duration (In Minutes)</th> 
              </tr>
              <tr>
                <td>Getting Started</td>
                <td>20</td> 
              </tr>
              <tr>
                <td>Setting up the Environment</td>
                <td>40</td> 
              </tr>
              <tr>
                <td>Extracting Data</td>
                <td>35</td> 
              </tr>
              <tr>
                <td>Exploring and Processing Data - Part 1</td>
                <td>45</td> 
              </tr>
              <tr>
                <td>Exploring and Processing Data - Part 2</td>
                <td>45</td> 
              </tr>
              <tr>
                <td>Building Predictive Model</td>
                <td>30</td> 
              </tr>
          </table>
    </body>
    </html>
    '''

# %%
from IPython.core.display import display, HTML
display(HTML(html_string))
# Out:
# <!doctype html>
# <html lang="en">
#     "<head>
#           <title>Doing Data Science With Python</title>
#     </head>
#     <body>
#           <h1 style="color:#F15B2A;">Doing Data Science With Python</h1>
#           <p id="author">Author : Abhishek Kumar</p>
#     <p id="description">This course will help you to perform various data science activities using python.</p>
#
#           <h3 style="color:#404040">Modules</h3>
#           <table id="module" style="width:100%">
#               <tr>
#                 <th>Title</th>
#                 <th>Duration (In Minutes)</th>
#               </tr>
#               <tr>
#                 <td>Getting Started</td>
#                 <td>20</td>
#               </tr>
#               <tr>
#                 <td>Setting up the Environment</td>
#                 <td>40</td>
#               </tr>
#               <tr>
#                 <td>Extracting Data</td>
#                 <td>35</td>
#               </tr>
#               <tr>
# ...

# %% [markdown]
# ### TO DO:  Web Scraping using Request & BeautifulSoup

# %% [markdown]
# ### IMPORTING TITANIC DATASET

# %% [markdown]
# #### Using Environment variable abd request.session

# %%
#STEP1: Uusing Atom, open below foldeR:
#/Users/pinky/Downloads/LEARNING/PLURALSIGHT_Python_data_science_Abhishek_kumar/module2/titanic

#STEP2: Add below lines to .env
# Added by Ganesh Pillai on 09/10/2018
# KAGGLE_USERNAME=ganesh33@hotmail.com
# KAGGLE_PASSWORD=newpass

#STEP3: Make sure .gitignore has below lines:
## DotEnv configuration
# .env

# %%
# !pip install python-dotenv
# O: Installing collected packages: python-dotenv
#    Successfully installed python-dotenv-0.9.1
# Out:
# ...
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# FIND .env automatically by walking up directories until its found
from dotenv import load_dotenv, find_dotenv
dotenv_path = find_dotenv()

#LOAD up the entries as environment variables 
# project_dir = os.path.join(os.path.dirname(__name__), os.pardir)
# project_dir  # ..
dotenv_path = os.path.join('titanic', '.env')  # # titanic/.env 
load_dotenv(dotenv_path)
# Out:
# True

# %%
# extreact environment variable using os.environ.get
import os
KAGGLE_USERNAME = os.environ.get('KAGGLE_USERNAME') 
print(KAGGLE_USERNAME)
KAGGLE_PASSWORD = os.environ.get('KAGGLE_PASSWORD') 
print(KAGGLE_PASSWORD)
# Out:
# ganesh33@hotmail.com
# newpass

# %%
# IMPORT request.session
from requests import session

# %%
payload = {
    'action': 'login',
    'username' : os.environ.get('KAGGLE_USERNAME'),
    'password' : os.environ.get('KAGGLE_PASSWORD') 
}


# DOESN'T WORK there is no url for train.csv
#url = 'https://www.kaggle.com/c/titanic/download/train.csv'
#url = 'https://www.kaggle.com/c/3136/download-all'


# with session() as myRequestSession:
#     myRequestSession.post('https://www.kaggle.com/account/login', data=payload)
#     response = myRequestSession.get(url)
#     print (response.headers)
#     print (response.encoding, response.cookies)
#     print(response.text)

# %% [markdown]
# #### Using pandas

# %%
raw_data_path = os.path.join('titanic','data', 'raw')  #../data/raw'
train_data_path = os.path.join(raw_data_path, 'train.csv') # '../data/raw/train.csv'
test_data_path = os.path.join(raw_data_path, 'test.csv') # '../data/raw/test.csv'

# %%
import pandas as pd
train_data = pd.read_csv(train_data_path)

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### LOGGING

# %% [raw]
# Levels: DEBUG, INFO, WARNING, ERROR, CRITICAL or NOTSET
# NOTE: NOTSET means all messages will be logged

# %%
import logging

'''
# create file handler which logs even debug messages
fileLogger = logging.FileHandler('pluralsight_python_datascience_abhishek.log')
fileLogger.setLevel(logging.DEBUG) 

# create console handler with a higher log level
consoleStreamingLogger = logging.StreamHandler()
consoleStreamingLogger.setLevel(logging.ERROR)
 
# create formatter and add it to the handlers
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
consoleStreamingLogger.setFormatter(formatter)
consoleStreamingLogger.setFormatter(formatter)

# add the handlers to the logger
logger.addHandler(fileLogger)
logger.addHandler(consoleStreamingLogger)

logger = logging.getLogger(name=__name__)
logger.setLevel(logging.DEBUG)

print(logger.level)
logger.level = logging.DEBUG

logger.debug('This is debug message')
logger.info('This is info message')
# logger.warn('This is warn message') # DeprecationWarning: The 'warn' method is deprecated
logger.warning('This is warning message')
logger.error('This is error message')  # 2018-09-11 19:29:27,348 - __main__ - ERROR - This is error message
logger.fatal('This is fatal message') # 2018-09-11 19:29:27,362 - __main__ - CRITICAL - This is fatal message
logger.critical('This is critical message') # 2018-09-11 19:29:27,381 - __main__ - CRITICAL - This is critical message
'''
# Out:
# "\n# create file handler which logs even debug messages\nfileLogger = logging.FileHandler('pluralsight_python_datascience_abhishek.log')\nfileLogger.setLevel(logging.DEBUG) \n\n# create console handler with a higher log level\nconsoleStreamingLogger = logging.StreamHandler()\nconsoleStreamingLogger.setLevel(logging.ERROR)\n \n# create formatter and add it to the handlers\nformatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')\nconsoleStreamingLogger.setFormatter(formatter)\nconsoleStreamingLogger.setFormatter(formatter)\n\n# add the handlers to the logger\nlogger.addHandler(fileLogger)\nlogger.addHandler(consoleStreamingLogger)\n\nlogger = logging.getLogger(name=__name__)\nlogger.setLevel(logging.DEBUG)\n\nprint(logger.level)\nlogger.level = logging.DEBUG\n\nlogger.debug('This is debug message')\nlogger.info('This is info message')\n# logger.warn('This is warn message') # DeprecationWarning: The 'warn' method is deprecated\nlogger.warning('This is warni
# ...

# %%
# WORKS
import logging
from logging.config import fileConfig

#logging.config.fileConfig('titanic/logging/logging.conf')
fileConfig('titanic/logging/logging.conf')

# create logger
logger = logging.getLogger()

# 'application' code
logger.debug('debug message')
logger.info('info message')
logger.warning('warn message')
logger.error('error message')
logger.critical('critical message')
# Out:
# 2018-09-11 21:47:15,639 - root - ERROR - error message
# 2018-09-11 21:47:15,642 - root - CRITICAL - critical message

# %% [markdown]
# #### TO DO: LOGGING USING YAML config file

# %% [markdown]
# ### OS INFO

# %%
os.path.dirname(os.pardir)
# Out:
# ''

# %%
os.pardir
# Out:
# '..'

# %%
os.curdir
# Out:
# '.'

# %%
os.environ
# Out:
# environ({'KAFKA_HOME': '/Users/pinky/Downloads/SOFTWARE/kafka_2.11-1.0.0', 'SPARK_HOME': '/Users/pinky/Downloads/SOFTWARE/spark-2.3.1-bin-hadoop2.7', 'TERM_PROGRAM': 'Apple_Terminal', 'SHELL': '/bin/bash', 'TERM': 'xterm-color', 'TMPDIR': '/var/folders/cv/tlhjv00d1jn9yb_c725pk_9c0000gn/T/', 'Apple_PubSub_Socket_Render': '/private/tmp/com.apple.launchd.ATuYeDNSeU/Render', 'TERM_PROGRAM_VERSION': '361.1', 'KAFKA_CONF_DIF': '/Users/pinky/Downloads/SOFTWARE/kafka_2.11-1.0.0/config', 'TERM_SESSION_ID': '4F9F4B43-F955-4E52-9741-43F58FEFA5F3', 'USER': 'ganeshpillai', 'KAFKA_CLASSPATH': '/Users/pinky/Downloads/SOFTWARE/kafka_2.11-1.0.0/libs', 'CANOPY_HOME': '/Users/pinky/Library/Enthought/Canopy_64bit/User/', 'SSH_AUTH_SOCK': '/private/tmp/com.apple.launchd.HudQKtxW6X/Listeners', '__CF_USER_TEXT_ENCODING': '0x1F5:0x0:0x0', 'VIRTUAL_ENV': '/Users/pinky/Library/Enthought/Canopy_64bit/User', 'PATH': '/anaconda3/bin:/anaconda3/bin:/Users/pinky/Downloads/SOFTWARE/google-cloud-sdk/bin:/Users/pinky
# ...

# %%
# !pwd
# Out:
# /Users/pinky/Downloads/LEARNING/PLURALSIGHT_Python_data_science_Abhishek_kumar/module2

# %%
my_folder= !pwd

# %%
my_folder
# Out:
# ['/Users/pinky/Downloads/LEARNING/PLURALSIGHT_Python_data_science_Abhishek_kumar/module2']

# %%
os.getcwd()
# Out:
# '/Users/pinky/Downloads/LEARNING/PLURALSIGHT_Python_data_science_Abhishek_kumar/module2'

# %%
os.getegid()
# Out:
# 20

# %%
os.getenv('SPARK_HOME')
# Out:
# '/Users/pinky/Downloads/SOFTWARE/spark-2.3.1-bin-hadoop2.7'

# %%
os.path.abspath(__name__)
# Out:
# '/Users/pinky/Downloads/LEARNING/PLURALSIGHT_Python_data_science_Abhishek_kumar/module2/__main__'

# %%
os.pardir
# Out:
# '..'

# %% [markdown]
# ### PUBLIC DATASETS

# %%
https://www.data.gov/
http://archive.ics.uci.edu/ml/datasets.html
https://github.com/awesomedata/awesome-public-datasets
    
    
https://cloud.google.com/public-datasets/
AWS public datasets

# %% [markdown]
# ### CONTINUE
