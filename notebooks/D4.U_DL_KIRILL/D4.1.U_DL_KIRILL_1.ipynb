# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import keras
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# LIBRARIES 
    1) THEANO
        -> open source numerical computations library
        -> efficient fast numerical computations; 
        -> numpy syntax
        -> can run on CPUs & GPUs(more cores;higher floating point calculations per second)
    2) TENSORFLOW
    3) KERAS

# %%
'''
# !pip install tensorflow
# !pip install theano
# !pip install keras

Collecting theano
  Downloading https://files.pythonhosted.org/packages/4d/b1/d490d88ab47f01f367f413bd2e47d86acf92c84157c5172c23903798bd70/Theano-1.0.3.tar.gz (2.8MB)
    100% |████████████████████████████████| 2.8MB 4.5MB/s eta 0:00:01    40% |████████████▉                   | 1.1MB 686kB/s eta 0:00:03    44% |██████████████▏                 | 1.2MB 3.2MB/s eta 0:00:01
Requirement already satisfied: numpy>=1.9.1 in /anaconda3/lib/python3.6/site-packages (from theano) (1.15.2)
Requirement already satisfied: scipy>=0.14 in /anaconda3/lib/python3.6/site-packages (from theano) (1.1.0)
Requirement already satisfied: six>=1.9.0 in /anaconda3/lib/python3.6/site-packages (from theano) (1.11.0)
Building wheels for collected packages: theano
  Running setup.py bdist_wheel for theano ... done
  Stored in directory: /Users/pinky/Library/Caches/pip/wheels/10/82/05/9ef5e43bfcf906b4810f85f91b09d6daf7ad213d30179defa9
Successfully built theano
tensorflow 1.10.0 has requirement numpy<=1.14.5,>=1.13.3, but you'll have numpy 1.15.2 which is incompatible.
Installing collected packages: theano
Successfully installed theano-1.0.3
'''
# Out:
# "\n!pip install theano\n\nCollecting theano\n  Downloading https://files.pythonhosted.org/packages/4d/b1/d490d88ab47f01f367f413bd2e47d86acf92c84157c5172c23903798bd70/Theano-1.0.3.tar.gz (2.8MB)\n    100% |████████████████████████████████| 2.8MB 4.5MB/s eta 0:00:01    40% |████████████▉                   | 1.1MB 686kB/s eta 0:00:03    44% |██████████████▏                 | 1.2MB 3.2MB/s eta 0:00:01\nRequirement already satisfied: numpy>=1.9.1 in /anaconda3/lib/python3.6/site-packages (from theano) (1.15.2)\nRequirement already satisfied: scipy>=0.14 in /anaconda3/lib/python3.6/site-packages (from theano) (1.1.0)\nRequirement already satisfied: six>=1.9.0 in /anaconda3/lib/python3.6/site-packages (from theano) (1.11.0)\nBuilding wheels for collected packages: theano\n  Running setup.py bdist_wheel for theano ... done\n  Stored in directory: /Users/pinky/Library/Caches/pip/wheels/10/82/05/9ef5e43bfcf906b4810f85f91b09d6daf7ad213d30179defa9\nSuccessfully built theano\ntensorflow 1.10.0 has requirement numpy<=1.14.5,>=1.13.3, but you'll have numpy 1.15.2 which is incompatible.\nInstalling collected packages: theano\nSuccessfully installed theano-1.0.3\n"

# %%
# !conda update --all
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /anaconda3
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pandas-0.23.4              |   py36h6440ff4_0         9.3 MB
#     jupyterlab_server-0.2.0    |           py36_0          40 KB
#     jedi-0.13.1                |           py36_0         229 KB
#     backports-1.0              |           py36_1           4 KB
#     pyparsing-2.2.2            |           py36_0          97 KB
#     mpmath-1.0.0               |           py36_2         893 KB
#     pyproj-1.9.5.1             |   py36h833a5d7_1          54 KB
#     colorama-0.4.0             |           py36_0          23 KB
#     cryptography-2.3.1         |   py36hdbc3d79_0         540 KB
#     numba-0.40.0               |   py36h6440ff4_0         2.5 MB
#     pyodbc-4.0.24              |   py36h0a44026_0          60 KB
#     pluggy-0.7.1               |   py36h28b3542_0          25 KB
#     numpy-1.15.2               |   py36h6a91979_1          48 KB
#     atomicwrites-1.2.1         |           py36_0          11 KB
#     lxml-4.2.5                 |   py36hef8c89e_0         1.5 MB
#     bleach-3.0.2               |           py36_0         220 KB
#     future-0.16.0              |           py36_2         668 KB
#     nose-1.3.7                 |           py36_2         214 KB
#     py-1.7.0                   |           py36_0         138 KB
#     importlib_metadata-0.6     |           py36_0          21 KB
#     libcurl-7.61.1             |       hf30b1f0_0         457 KB
#     alabaster-0.7.12           |           py36_0          17 KB
#     pyqt-5.9.2                 |   py36h655552a_2         4.4 MB
#     imagesize-1.1.0            |           py36_0           9 KB
#     more-itertools-4.3.0       |           py36_0          83 KB
#     idna-2.7                   |           py36_0         132 KB
#     pycurl-7.43.0.2            |   py36hdbc3d79_0          62 KB
#     cffi-1.11.5                |   py36h6174b99_1         205 KB
#     pexpect-4.6.0              |           py36_0          77 KB
#     flask-cors-3.0.6           |           py36_0          20 KB
#     markupsafe-1.0             |   py36h1de35cc_1          23 KB
#     rope-0.11.0                |           py36_0         282 KB
#     notebook-5.7.0             |           py36_0         7.4 MB
#     blosc-1.14.4               |       hd9629dc_0         317 KB
#     pyflakes-2.0.0             |           py36_0          87 KB
#     scikit-image-0.14.0        |   py36h0a44026_1        23.4 MB
#     tornado-5.1.1              |   py36h1de35cc_0         662 KB
#     pyyaml-3.13                |   py36h1de35cc_0         160 KB
#     statsmodels-0.9.0          |   py36h1d22016_0         8.5 MB
#     mkl-2019.0                 |              118       154.4 MB
#     cloudpickle-0.6.1          |           py36_0          27 KB
#     ptyprocess-0.6.0           |           py36_0          23 KB
#     openpyxl-2.5.8             |           py36_0         337 KB
#     sqlalchemy-1.2.12          |   py36h1de35cc_0         1.6 MB
#     keyring-15.1.0             |           py36_0          46 KB
#     packaging-18.0             |           py36_0          33 KB
#     sphinx-1.8.1               |           py36_0         1.9 MB
#     python.app-2               |           py36_9         1.3 MB
#     qtpy-1.5.1                 |           py36_0          53 KB
#     mpc-1.1.0                  |       h6ef4df4_1          90 KB
#     distributed-1.23.3         |           py36_0         819 KB
#     jupyter_core-4.4.0         |           py36_0          63 KB
#     glob2-0.6                  |           py36_1          17 KB
#     conda-verify-3.1.1         |           py36_0          33 KB
#     pillow-5.3.0               |   py36hb68e598_0         550 KB
#     cython-0.29                |   py36h0a44026_0         2.1 MB
#     sphinxcontrib-websupport-1.1.0|           py36_1          36 KB
#     geos-3.6.2                 |       h5470d99_2         1.4 MB
#     sortedcollections-1.0.1    |           py36_0          15 KB
#     mccabe-0.6.1               |           py36_1          14 KB
#     bottleneck-1.2.1           |   py36h1d22016_1         113 KB
#     scipy-1.1.0                |   py36h28f7352_1        15.4 MB
#     pytables-3.4.4             |   py36h13cba08_0         1.4 MB
#     dask-core-0.19.4           |           py36_0         1.2 MB
#     html5lib-1.0.1             |           py36_0         184 KB
#     beautifulsoup4-4.6.3       |           py36_0         139 KB
#     mistune-0.8.4              |   py36h1de35cc_0          54 KB
#     gast-0.2.0                 |           py36_0          15 KB
#     arrow-0.12.1               |           py36_1          74 KB
#     xlwings-0.12.1             |           py36_0         433 KB
#     tensorflow-1.11.0          |mkl_py36h44b7a51_0           4 KB
#     pandocfilters-1.4.2        |           py36_1          13 KB
#     qtconsole-4.4.1            |           py36_0         156 KB
#     jupyterlab_launcher-0.13.1 |           py36_0          36 KB
#     anaconda-project-0.8.2     |           py36_0         478 KB
#     certifi-2018.10.15         |           py36_0         138 KB
#     anaconda-client-1.7.2      |           py36_0         141 KB
#     jupyter_console-6.0.0      |           py36_0          35 KB
#     scikit-learn-0.20.0        |   py36h4f467ca_1         5.4 MB
#     llvmlite-0.25.0            |   py36h8c7ce04_0        10.7 MB
#     attrs-18.2.0               |   py36h28b3542_0          50 KB
#     olefile-0.46               |           py36_0          48 KB
#     pytest-remotedata-0.3.0    |           py36_0          12 KB
#     tqdm-4.26.0                |   py36h28b3542_0          59 KB
#     sortedcontainers-2.0.5     |           py36_0          42 KB
#     gmpy2-2.0.8                |   py36h6ef4df4_2         162 KB
#     babel-2.6.0                |           py36_0         5.7 MB
#     multipledispatch-0.6.0     |           py36_0          21 KB
#     webencodings-0.5.1         |           py36_1          19 KB
#     lz4-c-1.8.1.2              |       h1de35cc_0         119 KB
#     imageio-2.4.1              |           py36_0         3.3 MB
#     jinja2-2.10                |           py36_0         184 KB
#     matplotlib-3.0.0           |   py36h54f8f79_0         6.8 MB
#     bitarray-0.8.3             |   py36h1de35cc_0          54 KB
#     ruamel_yaml-0.15.46        |   py36h1de35cc_0         228 KB
#     lazy-object-proxy-1.3.1    |   py36h1de35cc_2          29 KB
#     zict-0.1.3                 |           py36_0          18 KB
#     astor-0.7.1                |           py36_0          43 KB
#     greenlet-0.4.15            |   py36h1de35cc_0          18 KB
#     mkl_fft-1.0.6              |   py36hb8a8100_0         139 KB
#     curl-7.61.1                |       ha441bb4_0         135 KB
#     msgpack-python-0.5.6       |   py36h04f5b5a_1          89 KB
#     pycrypto-2.6.1             |   py36h1de35cc_9         452 KB
#     sphinxcontrib-1.0          |           py36_1           3 KB
#     prometheus_client-0.4.2    |           py36_0          63 KB
#     astroid-2.0.4              |           py36_0         247 KB
#     partd-0.3.9                |           py36_0          32 KB
#     sympy-1.3                  |           py36_0         9.5 MB
#     spyder-3.3.1               |           py36_1         2.6 MB
#     mkl_random-1.0.1           |   py36h5d10147_1         349 KB
#     astropy-3.0.4              |   py36h1de35cc_0         6.7 MB
#     testpath-0.4.2             |           py36_0          91 KB
#     nbconvert-5.3.1            |           py36_0         405 KB
#     kiwisolver-1.0.1           |   py36h0a44026_0          56 KB
#     networkx-2.2               |           py36_1         2.0 MB
#     parso-0.3.1                |           py36_0         114 KB
#     zstd-1.3.3                 |       h2a6be3a_0         561 KB
#     path.py-11.5.0             |           py36_0          55 KB
#     pytest-3.8.2               |           py36_0         328 KB
#     spyder-kernels-0.2.6       |           py36_0          69 KB
#     blaze-0.11.3               |           py36_0         603 KB
#     pylint-2.1.1               |           py36_0         795 KB
#     appscript-1.0.1            |   py36h1de35cc_1         129 KB
#     pycparser-2.19             |           py36_0         173 KB
#     pycosat-0.6.3              |   py36h1de35cc_0         107 KB
#     pywavelets-1.0.1           |   py36h1d22016_0         4.3 MB
#     seaborn-0.9.0              |           py36_0         379 KB
#     requests-2.19.1            |           py36_0          96 KB
#     conda-build-3.16.1         |           py36_0         474 KB
#     markdown-2.6.11            |           py36_0         103 KB
#     xlsxwriter-1.1.1           |           py36_0         212 KB
#     clyent-1.2.2               |           py36_1          19 KB
#     freetype-2.9.1             |       hb4e5f40_0         864 KB
#     jupyterlab-0.35.1          |           py36_0        10.5 MB
#     dask-0.19.4                |           py36_0           3 KB
#     pyzmq-17.1.2               |   py36h1de35cc_0         407 KB
#     gevent-1.3.7               |   py36h1de35cc_0         1.7 MB
#     protobuf-3.6.0             |   py36h0a44026_0         604 KB
#     boto-2.49.0                |           py36_0         1.5 MB
#     bokeh-0.13.0               |           py36_0         5.0 MB
#     click-7.0                  |           py36_0         118 KB
#     absl-py-0.5.0              |           py36_0         146 KB
#     numexpr-2.6.8              |   py36h1dc9127_0         126 KB
#     conda-env-2.6.0            |                1           3 KB
#     widgetsnbextension-3.4.2   |           py36_0         1.7 MB
#     proj4-5.0.1                |       h1de35cc_0         7.0 MB
#     pytest-astropy-0.4.0       |           py36_0           5 KB
#     python-libarchive-c-2.8    |           py36_6          20 KB
#     datashape-0.5.4            |           py36_1         100 KB
#     pickleshare-0.7.5          |           py36_0          12 KB
#     tensorflow-base-1.11.0     |mkl_py36h70e0e9a_0        83.3 MB
#     unixodbc-2.3.7             |       h1de35cc_0         271 KB
#     itsdangerous-0.24          |           py36_1          21 KB
#     entrypoints-0.2.3          |           py36_2           9 KB
#     pyshp-1.2.12               |           py36_0          35 KB
#     h5py-2.8.0                 |   py36h878fce3_3         913 KB
#     six-1.11.0                 |           py36_1          21 KB
#     ipython-7.0.1              |   py36h39e3cac_0         1.0 MB
#     mpfr-4.0.1                 |       h3018a27_3         526 KB
#     qtawesome-0.5.1            |           py36_1         569 KB
#     ipykernel-5.0.0            |   py36h39e3cac_0         156 KB
#     filelock-3.0.9             |           py36_0          13 KB
#     termcolor-1.1.0            |           py36_1           7 KB
#     _tflow_select-2.3.0        |              mkl           3 KB
#     psutil-5.4.7               |   py36h1de35cc_0         314 KB
#     tensorboard-1.11.0         |   py36hdc36e2c_0         3.1 MB
#     grpcio-1.12.1              |   py36hd9629dc_0         1.5 MB
#     pytz-2018.5                |           py36_0         231 KB
#     numpy-base-1.15.2          |   py36h8a80b8c_1         4.1 MB
#     urllib3-1.23               |           py36_0         152 KB
#     backports.shutil_get_terminal_size-1.0.0|           py36_2           8 KB
#     _ipyw_jlab_nb_ext_conf-0.1.0|           py36_0           4 KB
#     basemap-1.2.0              |   py36h0acbc05_0        15.1 MB
#     libarchive-3.3.3           |       hc2e69e3_1         1.5 MB
#     cytoolz-0.9.0.1            |   py36h1de35cc_1         350 KB
#     ipywidgets-7.4.2           |           py36_0         151 KB
#     mkl-service-1.1.2          |   py36h6b9c3cc_5           9 KB
#     prompt_toolkit-2.0.6       |           py36_0         466 KB
#     backports.os-0.1.1         |           py36_0          15 KB
#     xlrd-1.1.0                 |           py36_1         194 KB
#     typed-ast-1.1.0            |   py36h1de35cc_0         183 KB
#     wrapt-1.10.11              |   py36h1de35cc_2          41 KB
#     pytest-arraydiff-0.2       |   py36h39e3cac_0          14 KB
#     chardet-3.0.4              |           py36_1         189 KB
#     ------------------------------------------------------------
#                                            Total:       455.8 MB
#
# The following NEW packages will be INSTALLED:
#
#     _tflow_select:                      2.3.0-mkl
#     atomicwrites:                       1.2.1-py36_0
#     backports.os:                       0.1.1-py36_0
#     importlib_metadata:                 0.6-py36_0
#     jupyterlab_server:                  0.2.0-py36_0
#     keyring:                            15.1.0-py36_0
#     libarchive:                         3.3.3-hc2e69e3_1
#     lz4-c:                              1.8.1.2-h1de35cc_0
#     proj4:                              5.0.1-h1de35cc_0
#     prometheus_client:                  0.4.2-py36_0
#     pyproj:                             1.9.5.1-py36h833a5d7_1
#     pyshp:                              1.2.12-py36_0
#     python-libarchive-c:                2.8-py36_6
#     spyder-kernels:                     0.2.6-py36_0
#     tensorflow-base:                    1.11.0-mkl_py36h70e0e9a_0
#     tqdm:                               4.26.0-py36h28b3542_0
#     typed-ast:                          1.1.0-py36h1de35cc_0
#     zstd:                               1.3.3-h2a6be3a_0
#
# The following packages will be UPDATED:
#
#     _ipyw_jlab_nb_ext_conf:             0.1.0-py36h2fc01ae_0                  --> 0.1.0-py36_0
#     absl-py:                            0.5.0-py_0                conda-forge --> 0.5.0-py36_0
#     alabaster:                          0.7.10-py36h174008c_0                 --> 0.7.12-py36_0
#     anaconda-client:                    1.6.14-py36_0                         --> 1.7.2-py36_0
#     anaconda-project:                   0.8.2-py36h9ee5d53_0                  --> 0.8.2-py36_0
#     appscript:                          1.0.1-py36h9e71e49_1                  --> 1.0.1-py36h1de35cc_1
#     astor:                              0.7.1-py_0                conda-forge --> 0.7.1-py36_0
#     astroid:                            1.6.3-py36_0                          --> 2.0.4-py36_0
#     astropy:                            3.0.2-py36h917ab60_1                  --> 3.0.4-py36h1de35cc_0
#     attrs:                              18.1.0-py36_0                         --> 18.2.0-py36h28b3542_0
#     babel:                              2.5.3-py36_0                          --> 2.6.0-py36_0
#     backports:                          1.0-py36ha3c1827_1                    --> 1.0-py36_1
#     backports.shutil_get_terminal_size: 1.0.0-py36hd7a2ee4_2                  --> 1.0.0-py36_2
#     basemap:                            1.0.7-np113py36_0                     --> 1.2.0-py36h0acbc05_0
#     beautifulsoup4:                     4.6.0-py36h72d3c9f_1                  --> 4.6.3-py36_0
#     bitarray:                           0.8.1-py36h1de35cc_1                  --> 0.8.3-py36h1de35cc_0
#     blaze:                              0.11.3-py36h02e7a37_0                 --> 0.11.3-py36_0
#     bleach:                             2.1.3-py36_0                          --> 3.0.2-py36_0
#     blosc:                              1.14.3-hd9629dc_0                     --> 1.14.4-hd9629dc_0
#     bokeh:                              0.12.16-py36_0                        --> 0.13.0-py36_0
#     boto:                               2.48.0-py36hdbc59ac_1                 --> 2.49.0-py36_0
#     bottleneck:                         1.2.1-py36hbd380ad_0                  --> 1.2.1-py36h1d22016_1
#     certifi:                            2018.8.24-py36_1                      --> 2018.10.15-py36_0
#     cffi:                               1.11.5-py36h342bebf_0                 --> 1.11.5-py36h6174b99_1
#     chardet:                            3.0.4-py36h96c241c_1                  --> 3.0.4-py36_1
#     click:                              6.7-py36hec950be_0                    --> 7.0-py36_0
#     cloudpickle:                        0.5.3-py36_0                          --> 0.6.1-py36_0
#     clyent:                             1.2.2-py36hae3ad88_0                  --> 1.2.2-py36_1
#     colorama:                           0.3.9-py36hd29a30c_0                  --> 0.4.0-py36_0
#     conda-build:                        3.10.5-py36_0                         --> 3.16.1-py36_0
#     conda-env:                          2.6.0-h36134e3_0                      --> 2.6.0-1
#     conda-verify:                       2.0.0-py36he837df3_0                  --> 3.1.1-py36_0
#     cryptography:                       2.2.2-py36h1de35cc_0                  --> 2.3.1-py36hdbc3d79_0
#     curl:                               7.60.0-ha441bb4_0                     --> 7.61.1-ha441bb4_0
#     cython:                             0.28.2-py36h1de35cc_0                 --> 0.29-py36h0a44026_0
#     cytoolz:                            0.9.0.1-py36h1de35cc_0                --> 0.9.0.1-py36h1de35cc_1
#     dask:                               0.17.5-py36_0                         --> 0.19.4-py36_0
#     dask-core:                          0.17.5-py36_0                         --> 0.19.4-py36_0
#     datashape:                          0.5.4-py36hfb22df8_0                  --> 0.5.4-py36_1
#     distributed:                        1.21.8-py36_0                         --> 1.23.3-py36_0
#     entrypoints:                        0.2.3-py36hd81d71f_2                  --> 0.2.3-py36_2
#     expat:                              2.2.5-hb8e80ba_0                      --> 2.2.6-h0a44026_0
#     filelock:                           3.0.4-py36_0                          --> 3.0.9-py36_0
#     flask-cors:                         3.0.4-py36_0                          --> 3.0.6-py36_0
#     freetype:                           2.8-h12048fb_1                        --> 2.9.1-hb4e5f40_0
#     future:                             0.16.0-py36_2             conda-forge --> 0.16.0-py36_2
#     gast:                               0.2.0-py_0                conda-forge --> 0.2.0-py36_0
#     geos:                               3.5.0-0                               --> 3.6.2-h5470d99_2
#     gevent:                             1.3.0-py36h1de35cc_0                  --> 1.3.7-py36h1de35cc_0
#     glib:                               2.56.1-h35bc53a_0                     --> 2.56.2-hd9629dc_0
#     glob2:                              0.6-py36h94c9186_0                    --> 0.6-py36_1
#     gmpy2:                              2.0.8-py36hf9c35bd_2                  --> 2.0.8-py36h6ef4df4_2
#     greenlet:                           0.4.13-py36h1de35cc_0                 --> 0.4.15-py36h1de35cc_0
#     h5py:                               2.7.1-py36ha8ecd60_2                  --> 2.8.0-py36h878fce3_3
#     html5lib:                           1.0.1-py36h2f9c1c0_0                  --> 1.0.1-py36_0
#     idna:                               2.6-py36h8628d0a_1                    --> 2.7-py36_0
#     imageio:                            2.3.0-py36_0                          --> 2.4.1-py36_0
#     imagesize:                          1.0.0-py36_0                          --> 1.1.0-py36_0
#     intel-openmp:                       2018.0.0-8                            --> 2019.0-118
#     ipykernel:                          4.8.2-py36_0                          --> 5.0.0-py36h39e3cac_0
#     ipython:                            6.4.0-py36_0                          --> 7.0.1-py36h39e3cac_0
#     ipywidgets:                         7.2.1-py36_0                          --> 7.4.2-py36_0
#     itsdangerous:                       0.24-py36h49fbb8d_1                   --> 0.24-py36_1
#     jedi:                               0.12.0-py36_1                         --> 0.13.1-py36_0
#     jinja2:                             2.10-py36hd36f9c5_0                   --> 2.10-py36_0
#     jupyter_console:                    5.2.0-py36hccf5b1c_1                  --> 6.0.0-py36_0
#     jupyter_core:                       4.4.0-py36h79cf704_0                  --> 4.4.0-py36_0
#     jupyterlab:                         0.32.1-py36_0                         --> 0.35.1-py36_0
#     jupyterlab_launcher:                0.10.5-py36_0                         --> 0.13.1-py36_0
#     kiwisolver:                         1.0.1-py36h792292d_0                  --> 1.0.1-py36h0a44026_0
#     lazy-object-proxy:                  1.3.1-py36h2fbbe47_0                  --> 1.3.1-py36h1de35cc_2
#     libcurl:                            7.60.0-hf30b1f0_0                     --> 7.61.1-hf30b1f0_0
#     libprotobuf:                        3.6.0-hd28b015_0          conda-forge --> 3.6.0-hd9629dc_0
#     libtiff:                            4.0.9-hcb84e12_1                      --> 4.0.9-hcb84e12_2
#     llvmlite:                           0.23.1-py36hc454e04_0                 --> 0.25.0-py36h8c7ce04_0
#     lxml:                               4.2.1-py36h7166777_0                  --> 4.2.5-py36hef8c89e_0
#     markdown:                           2.6.11-py_0               conda-forge --> 2.6.11-py36_0
#     markupsafe:                         1.0-py36h3a1e703_1                    --> 1.0-py36h1de35cc_1
#     matplotlib:                         2.2.2-py36ha7267d0_0                  --> 3.0.0-py36h54f8f79_0
#     mccabe:                             0.6.1-py36hdaeb55d_0                  --> 0.6.1-py36_1
#     mistune:                            0.8.3-py36h1de35cc_1                  --> 0.8.4-py36h1de35cc_0
#     mkl:                                2018.0.2-1                            --> 2019.0-118
#     mkl-service:                        1.1.2-py36h7ea6df4_4                  --> 1.1.2-py36h6b9c3cc_5
#     mkl_fft:                            1.0.1-py36h917ab60_0                  --> 1.0.6-py36hb8a8100_0
#     mkl_random:                         1.0.1-py36h78cc56f_0                  --> 1.0.1-py36h5d10147_1
#     more-itertools:                     4.1.0-py36_0                          --> 4.3.0-py36_0
#     mpc:                                1.0.3-h7a72875_5                      --> 1.1.0-h6ef4df4_1
#     mpfr:                               3.1.5-h711e7fd_2                      --> 4.0.1-h3018a27_3
#     mpmath:                             1.0.0-py36hf1b8295_2                  --> 1.0.0-py36_2
#     msgpack-python:                     0.5.6-py36h04f5b5a_0                  --> 0.5.6-py36h04f5b5a_1
#     multipledispatch:                   0.5.0-py36_0                          --> 0.6.0-py36_0
#     networkx:                           2.1-py36_0                            --> 2.2-py36_1
#     nose:                               1.3.7-py36h73fae2b_2                  --> 1.3.7-py36_2
#     notebook:                           5.5.0-py36_0                          --> 5.7.0-py36_0
#     numba:                              0.38.0-py36h1702cab_0                 --> 0.40.0-py36h6440ff4_0
#     numexpr:                            2.6.5-py36h057f876_0                  --> 2.6.8-py36h1dc9127_0
#     numpy:                              1.13.3-py36ha9ae307_4                 --> 1.15.2-py36h6a91979_1
#     numpy-base:                         1.14.3-py36h479e554_1                 --> 1.15.2-py36h8a80b8c_1
#     olefile:                            0.45.1-py36_0                         --> 0.46-py36_0
#     openpyxl:                           2.5.3-py36_0                          --> 2.5.8-py36_0
#     packaging:                          17.1-py36_0                           --> 18.0-py36_0
#     pandas:                             0.23.0-py36h1702cab_0                 --> 0.23.4-py36h6440ff4_0
#     pandoc:                             1.19.2.1-ha5e8f32_1                   --> 2.2.3.2-0
#     pandocfilters:                      1.4.2-py36h3b0b094_1                  --> 1.4.2-py36_1
#     parso:                              0.2.0-py36_0                          --> 0.3.1-py36_0
#     partd:                              0.3.8-py36hf5c4cb8_0                  --> 0.3.9-py36_0
#     path.py:                            11.0.1-py36_0                         --> 11.5.0-py36_0
#     pexpect:                            4.5.0-py36_0                          --> 4.6.0-py36_0
#     pickleshare:                        0.7.4-py36hf512f8e_0                  --> 0.7.5-py36_0
#     pillow:                             5.1.0-py36hfcce615_0                  --> 5.3.0-py36hb68e598_0
#     pluggy:                             0.6.0-py36hb1d0581_0                  --> 0.7.1-py36h28b3542_0
#     prompt_toolkit:                     1.0.15-py36haeda067_0                 --> 2.0.6-py36_0
#     protobuf:                           3.6.0-py36hfc679d8_0      conda-forge --> 3.6.0-py36h0a44026_0
#     psutil:                             5.4.5-py36h1de35cc_0                  --> 5.4.7-py36h1de35cc_0
#     ptyprocess:                         0.5.2-py36he6521c3_0                  --> 0.6.0-py36_0
#     py:                                 1.5.3-py36_0                          --> 1.7.0-py36_0
#     pycosat:                            0.6.3-py36hee92d8f_0                  --> 0.6.3-py36h1de35cc_0
#     pycparser:                          2.18-py36h724b2fc_1                   --> 2.19-py36_0
#     pycrypto:                           2.6.1-py36h1de35cc_8                  --> 2.6.1-py36h1de35cc_9
#     pycurl:                             7.43.0.1-py36hdbc3d79_0               --> 7.43.0.2-py36hdbc3d79_0
#     pyflakes:                           1.6.0-py36hea45e83_0                  --> 2.0.0-py36_0
#     pylint:                             1.8.4-py36_0                          --> 2.1.1-py36_0
#     pyodbc:                             4.0.23-py36h0a44026_0                 --> 4.0.24-py36h0a44026_0
#     pyparsing:                          2.2.0-py36hb281f35_0                  --> 2.2.2-py36_0
#     pyqt:                               5.9.2-py36h11d3b92_0                  --> 5.9.2-py36h655552a_2
#     pytables:                           3.4.3-py36h5ca999c_2                  --> 3.4.4-py36h13cba08_0
#     pytest:                             3.5.1-py36_0                          --> 3.8.2-py36_0
#     pytest-arraydiff:                   0.2-py36_0                            --> 0.2-py36h39e3cac_0
#     pytest-astropy:                     0.3.0-py36_0                          --> 0.4.0-py36_0
#     pytest-remotedata:                  0.2.1-py36_0                          --> 0.3.0-py36_0
#     python:                             3.6.5-hc167b69_1                      --> 3.6.6-hc167b69_0
#     python.app:                         2-py36_8                              --> 2-py36_9
#     pytz:                               2018.4-py36_0                         --> 2018.5-py36_0
#     pywavelets:                         0.5.2-py36h2710a04_0                  --> 1.0.1-py36h1d22016_0
#     pyyaml:                             3.12-py36h2ba1e63_1                   --> 3.13-py36h1de35cc_0
#     pyzmq:                              17.0.0-py36h1de35cc_1                 --> 17.1.2-py36h1de35cc_0
#     qt:                                 5.9.5-h02808f3_0                      --> 5.9.6-h45cd832_2
#     qtawesome:                          0.4.4-py36h468c6fb_0                  --> 0.5.1-py36_1
#     qtconsole:                          4.3.1-py36hd96c0ff_0                  --> 4.4.1-py36_0
#     qtpy:                               1.4.1-py36_0                          --> 1.5.1-py36_0
#     readline:                           7.0-hc1231fa_4                        --> 7.0-h1de35cc_5
#     requests:                           2.18.4-py36h4516966_1                 --> 2.19.1-py36_0
#     rope:                               0.10.7-py36h68959ac_0                 --> 0.11.0-py36_0
#     ruamel_yaml:                        0.15.35-py36h1de35cc_1                --> 0.15.46-py36h1de35cc_0
#     scikit-image:                       0.13.1-py36h1de35cc_1                 --> 0.14.0-py36h0a44026_1
#     scikit-learn:                       0.19.1-py36hffbff8c_0                 --> 0.20.0-py36h4f467ca_1
#     scipy:                              1.1.0-py36hcaad992_0                  --> 1.1.0-py36h28f7352_1
#     seaborn:                            0.8.1-py36h595ecd9_0                  --> 0.9.0-py36_0
#     setuptools:                         39.1.0-py36_0                         --> 40.4.3-py36_0
#     six:                                1.11.0-py36h0e22d5e_1                 --> 1.11.0-py36_1
#     sortedcollections:                  0.6.1-py36_0                          --> 1.0.1-py36_0
#     sortedcontainers:                   1.5.10-py36_0                         --> 2.0.5-py36_0
#     sphinx:                             1.7.4-py36_0                          --> 1.8.1-py36_0
#     sphinxcontrib:                      1.0-py36h9364dc8_1                    --> 1.0-py36_1
#     sphinxcontrib-websupport:           1.0.1-py36h92f4a7a_1                  --> 1.1.0-py36_1
#     spyder:                             3.2.8-py36_0                          --> 3.3.1-py36_1
#     sqlalchemy:                         1.2.7-py36hb402a30_0                  --> 1.2.12-py36h1de35cc_0
#     sqlite:                             3.23.1-hf1716c9_0                     --> 3.25.2-ha441bb4_0
#     statsmodels:                        0.9.0-py36h917ab60_0                  --> 0.9.0-py36h1d22016_0
#     sympy:                              1.1.1-py36h7f3cf04_0                  --> 1.3-py36_0
#     tensorboard:                        1.10.0-py36_0             conda-forge --> 1.11.0-py36hdc36e2c_0
#     tensorflow:                         1.10.0-py36_0             conda-forge --> 1.11.0-mkl_py36h44b7a51_0
#     testpath:                           0.3.1-py36h625a49b_0                  --> 0.4.2-py36_0
#     tk:                                 8.6.7-h35a86e2_3                      --> 8.6.8-ha441bb4_0
#     tornado:                            5.0.2-py36_0                          --> 5.1.1-py36h1de35cc_0
#     unixodbc:                           2.3.6-h3efe00b_0                      --> 2.3.7-h1de35cc_0
#     urllib3:                            1.22-py36h68b9469_0                   --> 1.23-py36_0
#     webencodings:                       0.5.1-py36h3b9701d_1                  --> 0.5.1-py36_1
#     wheel:                              0.31.1-py36_0                         --> 0.32.1-py36_0
#     widgetsnbextension:                 3.2.1-py36_0                          --> 3.4.2-py36_0
#     wrapt:                              1.10.11-py36hc29e774_0                --> 1.10.11-py36h1de35cc_2
#     xlrd:                               1.1.0-py36h336f4a2_1                  --> 1.1.0-py36_1
#     xlsxwriter:                         1.0.4-py36_0                          --> 1.1.1-py36_0
#     xlwings:                            0.11.8-py36_0                         --> 0.12.1-py36_0
#     zeromq:                             4.2.5-h378b8a2_0                      --> 4.2.5-h0a44026_1
#     zict:                               0.1.3-py36h71da714_0                  --> 0.1.3-py36_0
#
# The following packages will be DOWNGRADED:
#
#     arrow:                              0.12.1-py36_2             conda-forge --> 0.12.1-py36_1
#     grpcio:                             1.14.1-py36hd60e7a3_0     conda-forge --> 1.12.1-py36hd9629dc_0
#     nbconvert:                          5.4.0-py36_1                          --> 5.3.1-py36_0
#     termcolor:                          1.1.0-py_2                conda-forge --> 1.1.0-py36_1
#
# Proceed ([y]/n)?
