# %% [markdown]
# ### HouseKeeping

# %%
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image

# %% [markdown]
# ### Drawing on images with mouse - Part1

# %%
Image(filename='../images/UDEMY_computer_vision_Joseph_Portilla/computer_vision2_OpenCV2.PNG', height=500, width=800)

# %%
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


# FUNCTION
def draw_circle(event, x, y, flags, param):
    #pass
    if event == cv2.EVENT_LBUTTONDOWN:
        r = np.random.randint(0,255)
        g = np.random.randint(0,255)
        b = np.random.randint(0,255)
        choose_one_zero = np.random.randint(0,3)
        if choose_one_zero == 0:
            r = 0
        elif choose_one_zero == 1:
            g = 0
        else:
            b = 0
        print (r, g, b)
        cv2.circle(image3, (x, y), color = (r, g, b), radius = np.random.randint(5,30), thickness = -1) 


cv2.namedWindow(winname = 'my_circle1')

#cv2.setMouseCallback(windowName = 'my_circle1', onMouse= draw_circle)
cv2.setMouseCallback('my_circle1', draw_circle)


# SHOW IMAGE WITH OPENCV
#image3 = np.zeros((512, 512,3), np.int8)
image3 = np.zeros((512, 512,3))

while True:
    #print('inside while loop')
    cv2.imshow('my_circle1', image3)
    if cv2.waitKey(10) & 0xFF == 27:
        print('breaking')
        break

cv2.destroyAllWindows()
# Out:
# 0 84 36
# 33 0 250
# 0 141 211
# 170 128 0
# 82 221 0
# 222 0 150
# 233 0 39
# 136 156 0
# 0 177 15
# 234 0 11
# 131 95 0
# 0 189 113
# 236 0 227
# 21 0 102
# 96 0 126
# breaking

# %%
#function
def draw_square(event, x, y, flags, params):
    if event == cv2.EVENT_RBUTTONDOWN:
        cv2.rectangle(image4, (x, y), (x+ 50, y + 50), color= (255, 0 ,0))
        

cv2.namedWindow('my_square')
cv2.setMouseCallback('my_square', draw_square)

#show
image4 = np.ones((512, 512,3))

while True:
    cv2.imshow('my_square', image4) 
    if cv2.waitKey(10) &  0xFF == 27:
        break
cv2.destroyAllWindows()

# %% [markdown]
# ### Drawing on images with mouse - Part2

# %%
# TO DO : Combine above 2 codes

# %% [markdown]
# ### Drawing on images with mouse - Part3

# %%
# function
x_start = 0
y_start = 0
draw = False
def drag_to_create_square(event, x, y, flags, params):
    global x_start, y_start, draw 
    if event == cv2.EVENT_LBUTTONDOWN:
        x_start = x
        y_start = y
        draw = True
    elif event == cv2.EVENT_MOUSEMOVE:
        if draw: 
            cv2.rectangle(image5, (x_start, y_start), (x,y), color = (255, 0, 0),  thickness = -1)
    elif event == cv2.EVENT_LBUTTONUP:
        draw = False
        #cv2.rectangle(image5, (x_start, y_start), (x,y), color = (255, 0, 0),  thickness = -1)
        
cv2.namedWindow('my_drag_square')
cv2.setMouseCallback('my_drag_square', drag_to_create_square)

#show image
image5 = np.ones((512, 512, 3))

while True:
    cv2.imshow('my_drag_square', image5)
    if cv2.waitKey(20) & 0xFF == 27:
        break
cv2.destroyAllWindows()

# %%
#END
